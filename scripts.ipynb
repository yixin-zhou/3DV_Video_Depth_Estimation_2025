# %% [markdown]
# ### 1. 数据增强模块augmentor的测试demo

# %%
# %load_ext autoreload
# %autoreload 2

from datasets.augmentor import VideoSeqAugmentor
from PIL import Image
import matplotlib.pyplot as plt
from utils.viz_utils import viz_disparity
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def viz_two(left, right):
    plt.figure(figsize=(16, 8))
    plt.subplot(1, 2, 1)
    plt.imshow(left)
    plt.title("Left Image")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(right)
    plt.title("Right Image")
    plt.axis("off")

    plt.tight_layout()
    plt.show()


left = np.array(Image.open("data/samples/left.jpg").convert("RGB"))
right = np.array(Image.open("data/samples/right.jpg").convert("RGB"))
disp = np.load("data/samples/disparity_00026.npy.npz")['disparity']
viz_two(left, right)
viz_disparity(disp)

# %%
seq=[[left, right]]
disp = [disp]
augmentor = VideoSeqAugmentor(crop_size=(512, 256))

# %%
aug_seq, aug_disp= augmentor(seq, disp)
viz_two(aug_seq[0][0], aug_seq[0][1])
viz_disparity(aug_disp[0])
